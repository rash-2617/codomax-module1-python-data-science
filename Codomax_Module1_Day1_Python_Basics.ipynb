# %% [markdown]
# <a href="https://colab.research.google.com/github/rash-2617/codomax-module1-python-data-science/blob/main/Codomax_Module1_Day1_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CODOMAX INTERNSHIP

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Variables:** *a name used to store information*

# %%
name = "John"
age = 19
print(name , age)
# Out:
# John 19

# %% [markdown]
# # **Data Types**
#
#
# 1.  String: it is a text and this type is str

# %%
name = "John"
#print(type(name))

# %% [markdown]
# 2.   Integer : it is a whole number.The type is int.

# %%
age = 19

# %% [markdown]
# 3.   Float : A decimal number.this type is float.

# %%
cgpa = 8.16

# %% [markdown]
# 4.   Boolean : Either true or false.This type is bool.

# %%
is_student = True

# %%
print(type(name))
print(type(age))
print(type(cgpa))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Example

# %%
name = "John"
college = "XYZ"
Branch = "CS"
cgpa = 9.0
print(name , college , Branch , cgpa)
# Out:
# John XYZ CS 9.0

# %%
length = 10
width =5
Area = length * width
print("Area =",+ Area)
# Out:
# Area = 50

# %%
name = str(input("Enter your Name "))
age = int(input("Enter your Age "))
print("Hello"+name+".Your age is"+str(age))
# Out:
# Enter your Name Jane
# Enter your Age 20
# HelloJane.Your age is20

# %%
s1 = int(input("Enter a subject 1 marks:"))
s2 = int(input("Enter a subject 2 marks:"))
s3 = int(input("Enter a subject 3 marks:"))
total = s1+s2+s3
average = (s1+s2+s3)/3
print("Total :"+str(total))
print("Average :"+str(average))
# Out:
# Enter a subject 1 marks:98
# Enter a subject 2 marks:78
# Enter a subject 3 marks:90
# Total :266
# Average :88.66666666666667

# %%
name = str(input("Enter your Name "))
age = int(input("Enter your Age "))
branch = str(input("Enter your Branch "))
college = str(input("Enter your College "))
print("-----------STUDENT INFORMATION------------")
print("Name :",name)
print("Age :",age)
print("Branch :",branch)
print("College :",college)
# Out:
# Enter your Name Jake
# Enter your Age 19
# Enter your Branch CS
# Enter your College XYZ
# -----------STUDENT INFORMATION------------
# Name : Jake
# Age : 19
# Branch : CS
# College : XYZ
